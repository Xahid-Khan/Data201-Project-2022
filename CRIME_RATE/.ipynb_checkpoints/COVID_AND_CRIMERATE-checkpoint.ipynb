# %% [markdown]
# # Cleaning up the covid data for since 2020 till this year (2022).

# %%
library(visdat)
library(tidyverse)
library(readxl)
library(dplyr)
library(tidytext)
library(textdata)
library(rvest) # to scrape data from websites
library(xml2) # to effctively work with HTML or XML in R
library(magrittr)

# %%
options(repr.plot.width=15, repr.plot.height=8)

# %% [markdown]
# https://raw.githubusercontent.com/minhealthnz/nz-covid-data/main/cases/weekly-deaths.csvhttps://raw.githubusercontent.com/minhealthnz/nz-covid-data/main/cases/weekly-deaths.csv> We'll read the data straight from the ministry of Health git repository, that way if the data is updated, we'll get the latest dataset for covid cases from 2020 till todate.

# %%
covid_cases_data = read_csv("https://raw.githubusercontent.com/minhealthnz/nz-covid-data/main/cases/covid-cases.csv", col_names = TRUE)
# Out:
# Rows: 1809767 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (5): Case Status, Sex, Age group, DHB, Overseas travel
# lgl  (1): Historical
# date (1): Report Date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
covid_cases_data %>% tail()
# Out:
#   Report Date Case Status Sex    Age group DHB
# 1 2020-03-05  Probable    Male   70 to 79  Managed Isolation & Quarantine
# 2 2020-03-05  Probable    Female 70 to 79  Managed Isolation & Quarantine
# 3 2020-03-04  Confirmed   Male   40 to 49  Managed Isolation & Quarantine
# 4 2020-03-04  Confirmed   Male   40 to 49  Counties Manukau
# 5 2020-03-02  Confirmed   Female 30 to 39  Managed Isolation & Quarantine
# 6 2020-02-26  Confirmed   Female 60 to 69  Managed Isolation & Quarantine
#   Overseas travel Historical
# 1 Yes             NA
# 2 Yes             NA
# 3 Yes             NA
# 4 NA              NA
# 5 Yes             NA
# 6 Yes             NA

# %%
covid_cases_data %>% arrange('Report Date') %>% head()
colnames(covid_cases_data)[1] <- "Date"
covid_cases_data1 <- covid_cases_data
colnames(covid_cases_data1)[1] <- "Date"
# Out:
#   Report Date Case Status Sex    Age group DHB                  Overseas travel
# 1 2022-10-13  Confirmed   Male   90+       Southern             NA
# 2 2022-10-13  Confirmed   Female 20 to 29  MidCentral           NA
# 3 2022-10-13  Confirmed   Male   0 to 9    Capital & Coast/Hutt NA
# 4 2022-10-13  Confirmed   Female 0 to 9    Waitemata            NA
# 5 2022-10-13  Confirmed   Female 0 to 9    Waitemata            NA
# 6 2022-10-13  Confirmed   Male   30 to 39  Waitemata            NA
#   Historical
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
# covid_cases_data1$Date <- as.character(covid_cases_data1$Date)
# covid_cases_data1 %<>%
#     separate(Date, c("Year","Month", "Day"), "-")

# %%
# summarise_data_by_year <- covid_cases_data1 %>% group_by(Year) %>% summarise(total_cases = n())
# summarise_data_by_year

# %%
summarise_data_by_date <- covid_cases_data %>% group_by(Date) %>% summarise(total_cases = n())
summarise_data_by_date
# Out:
#     Date       total_cases
# 1   2020-02-26  1
# 2   2020-03-02  1
# 3   2020-03-04  2
# 4   2020-03-05  2
# 5   2020-03-06  1
# 6   2020-03-12  1
# 7   2020-03-13  1
# 8   2020-03-14  1
# 9   2020-03-15  1
# 10  2020-03-16  7
# 11  2020-03-17 12
# 12  2020-03-18  5
# 13  2020-03-19 18
# 14  2020-03-20 11
# 15  2020-03-21 24
# 16  2020-03-22 44
# 17  2020-03-23 41
# 18  2020-03-24 58
# 19  2020-03-25 84
# 20  2020-03-26 79
# 21  2020-03-27 75
# 22  2020-03-28 72
# 23  2020-03-29 74
# 24  2020-03-30 52
# 25  2020-03-31 77
# 26  2020-04-01 73
# 27  2020-04-02 82
# 28  2020-04-03 75
# 29  2020-04-04 77
# 30  2020-04-05 70
# ⋮   ⋮          ⋮
# 829 2022-09-14 1589
# 830 2022-09-15 1325
# 831 2022-09-16 1146
# 832 2022-09-17  885
# 833 2022-09-18 1022
# 834 2022-09-19 1817
# 835 2022-09-20 1622
# 836 2022-09-21 1649
# 837 2022-09-22 1540
# 838 2022-09-23 1289
# 839 2022-09-24  913
# 840 2022-09-25  954
# 841 2022-09-26 1256
# 842 2022-09-27 1939
# 843 2022-09-28 1660
# 844 2022-09-29 1576
# 845 2022-09-30 1446
# 846 2022-10-01  927
# 847 2022-10-02 1145
# 848 2022-10-03 1797
# 849 2022-10-04 1832
# 850 2022-10-05 1766
# 851 2022-10-06 1737
# 852 2022-10-07 1541
# 853 2022-10-08 1135
# 854 2022-10-09 1380
# 855 2022-10-10 2444
# 856 2022-10-11 2213
# 857 2022-10-12 2331
# 858 2022-10-13 2175

# %%
test_data_graph_by_date <- summarise_data_by_date %>% 
        ggplot(aes(x=Date, y=total_cases)) + 
        ggtitle('Total test cases in NZ from 2020 to 2022') + 
        geom_line(position = position_dodge(0.2), color="red") +
        # geom_point(position = position_dodge(0.2), size=2) +
        # geom_text(aes(label= total_cases), position=position_dodge(width=0.9), vjust=-0.75) +
        theme(plot.title = element_text(hjust = 0.5, size=18), 
              axis.title=element_text(size=17), 
              axis.text.x = element_text(size=13),
              axis.text.y = element_text(size=13),
              legend.title=element_blank(),
              legend.position = "right", 
              legend.text = element_text(size=14)) + 
        xlab("Time") + ylab("Test cases")
test_data_graph_by_date
# Out:
# plot without title

# %%
# ggsave(filename = "Total test cases in NZ from 2020 to 2022.png", test_data_graph_by_date,width = 70, height = 40, units = "cm")

# %%
summarise_data_by_city <- covid_cases_data %>% group_by(DHB) %>% summarise(total_cases = n())

# %%
summarise_data_by_city[summarise_data_by_city == "Auckland"] <- "Auckland City"
summarise_data_by_city[summarise_data_by_city == "Bay of Plenty"] <- "Bay Of Plenty"
summarise_data_by_city[summarise_data_by_city == "Canterbury/West Coast"] <- "Canterbury"
summarise_data_by_city[summarise_data_by_city == "MidCentral"] <- "Central"
summarise_data_by_city[summarise_data_by_city == "Counties Manukau"] <- "Counties/Manukau"
summarise_data_by_city[summarise_data_by_city == "Hawke's Bay"] <- "Eastern"
summarise_data_by_city[summarise_data_by_city == "Nelson Marlborough"] <- "Tasman"
summarise_data_by_city[summarise_data_by_city == "Capital & Coast/Hutt"] <- "Wellington"
colnames(summarise_data_by_city)[1] <- "district"
summarise_data_by_city
# Out:
#    district                       total_cases
# 1  Auckland City                  172086
# 2  Bay Of Plenty                   82780
# 3  Canterbury                     248193
# 4  Wellington                     185440
# 5  Counties/Manukau               208378
# 6  Eastern                         62161
# 7  Lakes                           36965
# 8  Managed Isolation & Quarantine  27218
# 9  Central                         64177
# 10 Tasman                          53561
# 11 Northland                       54497
# 12 South Canterbury                23663
# 13 Southern                       132065
# 14 Tairawhiti                      18092
# 15 Taranaki                        46464
# 16 Unknown                           932
# 17 Waikato                        143088
# 18 Wairarapa                       17357
# 19 Waitemata                      209407
# 20 Whanganui                       23243

# %% [markdown]
# Crime data was collected from the police NZ statistics website using the following URL:
# https://www.police.govt.nz/about-us/publications-statistics/data-and-statistics?nondesktop

# %%
crime_by_region <- read_csv("../Data/CrimeByRegion.csv", show_col_types = FALSE)
crime_by_region
colnames(crime_by_region) <- c("district", "year", "proceedings")
crime_by_region_bf <- crime_by_region %>% 
            filter(year < "2020") %>% 
            group_by(district) %>%
            summarize(proceedings = sum(proceedings))
# colnames(crime_by_region_bf)[2] <- "proceedings_precovid"
# crime_by_region_bf
crime_by_region_af <- crime_by_region %>% 
            filter(year > "2020") %>% 
            group_by(district) %>%
            summarize(proceedings = sum(proceedings))
# colnames(crime_by_region_af)[2] <- "proceedings_postcovid"
# crime_by_region_af
# Out:
#    Police District           Year of Year Month Proceedings
# 1  Not Specified (District)  2022                   3
# 2  Southern                  2022                4785
# 3  Canterbury                2022                7368
# 4  Tasman                    2022                3452
# 5  Wellington                2022                6254
# 6  Central                   2022                6887
# 7  Eastern                   2022                5777
# 8  Bay Of Plenty             2022                8810
# 9  Waikato                   2022                6955
# 10 Counties/Manukau          2022                9290
# 11 Auckland City             2022                6502
# 12 Waitemata                 2022                5938
# 13 Northland                 2022                3597
# 14 Not Specified (District)  2021                   5
# 15 Southern                  2021                7868
# 16 Canterbury                2021               11548
# 17 Tasman                    2021                5490
# 18 Wellington                2021               10023
# 19 Central                   2021               12263
# 20 Eastern                   2021                9132
# 21 Bay Of Plenty             2021               14135
# 22 Waikato                   2021               11388
# 23 Counties/Manukau          2021               13675
# 24 Auckland City             2021                9938
# 25 Waitemata                 2021                8847
# 26 Northland                 2021                6256
# 27 Not Specified (District)  2020                   3
# 28 Southern                  2020                9396
# 29 Canterbury                2020               14163
# 30 Tasman                    2020                6515
# ⋮  ⋮                         ⋮                  ⋮
# 37 Auckland City             2020               11500
# 38 Waitemata                 2020               10404
# 39 Northland                 2020                6815
# 40 PNHQ Licensing (District) 2019                   1
# 41 Not Specified (District)  2019                   2
# 42 Southern                  2019                9656
# 43 Canterbury                2019               14577
# 44 Tasman                    2019                6085
# 45 Wellington                2019               13172
# 46 Central                   2019               14137
# 47 Eastern                   2019               11168
# 48 Bay Of Plenty             2019               16579
# 49 Waikato                   2019               13965
# 50 Counties/Manukau          2019               17767
# 51 Auckland City             2019               11910
# 52 Waitemata                 2019               10799
# 53 Northland                 2019                6676
# 54 Not Specified (District)  2018                   6
# 55 Southern                  2018                7367
# 56 Canterbury                2018               10784
# 57 Tasman                    2018                4588
# 58 Wellington                2018                9895
# 59 Central                   2018               10865
# 60 Eastern                   2018                8401
# 61 Bay Of Plenty             2018               12183
# 62 Waikato                   2018               10307
# 63 Counties/Manukau          2018               15212
# 64 Auckland City             2018                9762
# 65 Waitemata                 2018                8646
# 66 Northland                 2018                5442

# %%
test_crime_bf_table <- merge(crime_by_region_bf, summarise_data_by_city, by="district")
test_crime_bf_table %<>% mutate(period = "Before")
# test_crime_bf_table
test_crime_af_table <- merge(crime_by_region_af, summarise_data_by_city, by="district")
test_crime_af_table %<>% mutate(period = "After")
# test_crime_af_table
total_crime_data_table <- test_crime_bf_table %>% rbind(test_crime_af_table)
# total_crime_data_table %<>% mutate(change_rate = round((proceedings_postcovid-proceedings_precovid)/proceedings_postcovid*100, 2))
# total_crime_data_table$proceedings%>%typeof()
# total_crime_data_table$total_cases%>%typeof()
total_crime_data_table
# Out:
#    district         proceedings total_cases period
# 1  Auckland City    21672       172086      Before
# 2  Bay Of Plenty    28762        82780      Before
# 3  Canterbury       25361       248193      Before
# 4  Central          25002        64177      Before
# 5  Counties/Manukau 32979       208378      Before
# 6  Eastern          19569        62161      Before
# 7  Northland        12118        54497      Before
# 8  Southern         17023       132065      Before
# 9  Tasman           10673        53561      Before
# 10 Waikato          24272       143088      Before
# 11 Waitemata        19445       209407      Before
# 12 Wellington       23067       185440      Before
# 13 Auckland City    16440       172086      After
# 14 Bay Of Plenty    22945        82780      After
# 15 Canterbury       18916       248193      After
# 16 Central          19150        64177      After
# 17 Counties/Manukau 22965       208378      After
# 18 Eastern          14909        62161      After
# 19 Northland         9853        54497      After
# 20 Southern         12653       132065      After
# 21 Tasman            8942        53561      After
# 22 Waikato          18343       143088      After
# 23 Waitemata        14785       209407      After
# 24 Wellington       16277       185440      After

# %%
total_crime_data_graph <- total_crime_data_table %>%
        ggplot(aes(x=district)) + 
        ggtitle('Crime rate by NZ districts before and after Covid') + 
        geom_bar(aes(y=total_cases/4, fill="Test cases"), stat = "identity", position = position_dodge(), alpha = 0.75, size = 0.5) +
        geom_bar(aes(y=proceedings, fill=period), stat = "identity", position = position_dodge(-0.9), alpha = 0.75, size = 0.5) +
        geom_text(aes(y=proceedings, label=proceedings, group=period), position=position_dodge(-0.9), vjust=-0.75) +
        geom_text(aes(y=total_cases/4, label=total_cases), position=position_dodge(width=0.2), vjust=-1) +
        theme(plot.title = element_text(hjust = 0.5, size=18), 
              axis.title=element_text(size=17), 
              axis.text.x = element_text(angle = 60, vjust = 1, hjust = 1, size=13),
              axis.text.y = element_text(size=13),
              legend.title=element_blank(),
              legend.position = "right", 
              legend.text = element_text(size=14)) + 
        scale_y_continuous(
                name = "crime cases",
                sec.axis = sec_axis(~.*4, name="Test cases")) +
        xlab("district")
total_crime_data_graph
# Out:
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# plot without title

# %%
# ggsave(filename = "Crime rate by NZ districts before and after Covid.png", total_crime_data_graph,width = 70, height = 40, units = "cm")

# %%
crime_types <- read_csv("../Data/CrimeType.csv", show_col_types = FALSE)
colnames(crime_types) <- c("type", "year", "method", "person", "area", "district", "month", "ethnicity", "subdivision", "proceedings")
crime_types$proceedings <- as.numeric(crime_types$proceedings)
crime_type_data <- crime_types %>% group_by(type, year) %>% summarise(cases=sum(proceedings))
crime_type_data %<>% 
        filter(year != 2020) %>% 
        mutate(period = if_else(year < 2020, "Before", "After")) %>% 
        group_by(type, period) %>% 
        summarise(cases = sum(cases))
crime_type_data
# crime_type_converter <- crime_types %>% 
#         select(-year) %>%
#         group_by(type) %>%
#         summarise(cases = sum(proceedings)) %>%
#         mutate(type_num = rownames(crime_type_converter)) %>%
#         select(-cases)
# crime_type_converter

# total_crime_type_table <- merge(crime_type_data, crime_type_converter, by="type")
# total_crime_type_table
# Out:
# `summarise()` has grouped output by 'type'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'type'. You can override using the
# `.groups` argument.
#    type                                                              period
# 1  Abduction, Harassment and Other Related Offences Against a Person After
# 2  Abduction, Harassment and Other Related Offences Against a Person Before
# 3  Acts Intended to Cause Injury                                     After
# 4  Acts Intended to Cause Injury                                     Before
# 5  Dangerous or Negligent Acts Endangering Persons                   After
# 6  Dangerous or Negligent Acts Endangering Persons                   Before
# 7  Fraud, Deception and Related Offences                             After
# 8  Fraud, Deception and Related Offences                             Before
# 9  Homicide and Related Offences                                     After
# 10 Homicide and Related Offences                                     Before
# 11 Illicit Drug Offences                                             After
# 12 Illicit Drug Offences                                             Before
# 13 Miscellaneous Offences                                            After
# 14 Miscellaneous Offences                                            Before
# 15 Offences Against Justice Procedures, Govt Sec and Govt Ops        After
# 16 Offences Against Justice Procedures, Govt Sec and Govt Ops        Before
# 17 Prohibited and Regulated Weapons and Explosives Offences          After
# 18 Prohibited and Regulated Weapons and Explosives Offences          Before
# 19 Property Damage and Environmental Pollution                       After
# 20 Property Damage and Environmental Pollution                       Before
# 21 Public Order Offences                                             After
# 22 Public Order Offences                                             Before
# 23 Robbery, Extortion and Related Offences                           After
# 24 Robbery, Extortion and Related Offences                           Before
# 25 Sexual Assault and Related Offences                               After
# 26 Sexual Assault and Related Offences                               Before
# 27 Theft and Related Offences                                        After
# 28 Theft and Related Offences                                        Before
# 29 Traffic and Vehicle Regulatory Offences                           After
# 30 Traffic and Vehicle Regulatory Offences                           Before
# 31 Unlawful Entry With Intent/Burglary, Break and Enter              After
# 32 Unlawful Entry With Intent/Burglary, Break and Enter              Before
#    cases
# 1   7573
# 2   9443
# 3  28829
# 4  38618
# 5  22238
# 6  27245
# 7   4050
# 8   5273
# 9    325
# 10   390
# 11 10998
# 12 16187
# 13  1154
# 14  1118
# 15 21131
# 16 29456
# 17  5820
# 18  6916
# 19  7373
# 20 10180
# 21 12196
# 22 21550
# 23  2045
# 24  2467
# 25  3001
# 26  3184
# 27 22477
# 28 30273
# 29 39032
# 30 48082
# 31  7944
# 32  9570

# %%
crime_type_data_graph <- crime_type_data %>%
        ggplot(aes(x=type, y=cases, fill=period)) + 
        ggtitle('Crime rate by crime type in NZ before and after Covid') + 
        geom_bar(stat = "identity", position = position_dodge(width = -0.9), alpha = 0.75, size = 0.5, width = 0.75) +
        geom_text(aes(label=cases, color = period), position=position_dodge(width = -0.9), vjust=-0.15) +
        theme(plot.title = element_text(hjust = 0.5, size=18), 
              axis.title=element_text(size=17), 
              axis.text.x = element_text(angle = 60, vjust = 1, hjust = 1, size=13),
              axis.text.y = element_text(size=13),
              legend.title=element_blank(),
              legend.position = "right", 
              legend.text = element_text(size=14)) + 
        xlab("crime type") + ylab("cases")
crime_type_data_graph
# Out:
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# plot without title

# %%
# ggsave(filename = "Crime rate by crime type in NZ before and after Covid.png", crime_type_data_graph, width = 70, height = 40, units = "cm")
# Out:
# Warning message:
# “position_dodge requires non-overlapping x intervals”
